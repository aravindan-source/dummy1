# %% [markdown]
# ![IMG_6956.jpeg](attachment:IMG_6956.jpeg)

# %% [markdown]
# #### Python Data Types
# - Mutable Data Types
#     - List
#     - Dictionary
#     - Set
# - Immutable Data Types
#     - int, float, string
#     - tuples, Bool

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
